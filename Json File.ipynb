# %%
import json

# %%
with open("jason_file.json",mode = "r")as file:
    content = json.load(file)

# %%
content
# Out:
# {'user': {'id': 101,
#   'name': 'Aaditya Saini',
#   'email': 'aaditya@example.com',
#   'age': 22,
#   'isActive': True},
#  'skills': ['HTML', 'CSS', 'JavaScript', 'Python', 'SQL'],
#  'address': {'city': 'Delhi', 'state': 'Delhi', 'country': 'India'},
#  'projects': [{'projectId': 1,
#    'title': 'Portfolio Website',
#    'status': 'Completed'},
#   {'projectId': 2,
#    'title': 'Data Analysis Dashboard',
#    'status': 'In Progress'}]}

# %%
content["user"]["isActive"] = False

# %%
content
# Out:
# {'user': {'id': 101,
#   'name': 'Aaditya Saini',
#   'email': 'aaditya@example.com',
#   'age': 22,
#   'isActive': False},
#  'skills': ['HTML', 'CSS', 'JavaScript', 'Python', 'SQL'],
#  'address': {'city': 'Delhi', 'state': 'Delhi', 'country': 'India'},
#  'projects': [{'projectId': 1,
#    'title': 'Portfolio Website',
#    'status': 'Completed'},
#   {'projectId': 2,
#    'title': 'Data Analysis Dashboard',
#    'status': 'In Progress'}],
#  'isActive': False}

# %%
with open("jason_file.json",mode = "w")as file:
    json.dump(content,file)
