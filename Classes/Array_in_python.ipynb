# %%
import array

# %%
number = array.array("B", [1,2,3,1,156])

# %%
type(number)
# Out:
# array.array

# %%
print(number)
# Out:
# array('B', [1, 2, 3, 1, 156])

# %%
# ager size check karna hai to

import sys
sys.getsizeof(number)
# Out:
# 85

# %%
number.typecode
# Out:
# 'B'

# %%
#  multiple data ko ek sath store karne ka liya eska use karta hai
