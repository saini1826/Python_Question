# %%
import json

# %%
with open("file_txt.json",mode = "r")as file:
    content = json.load(file)

# %%
content
# Out:
# {'metadata': {'requestId': 'req-9f23ab12',
#   'generatedAt': '2025-12-16T08:45:00Z',
#   'source': 'sample-data-generator',
#   'version': '1.0.0'},
#  'organization': {'id': 'org-1001',
#   'name': 'Acme Corporation',
#   'industry': 'Technology',
#   'isActive': True,
#   'contact': {'email': 'contact@acme.com', 'phone': '+1-555-123-4567'},
#   'locations': [{'locationId': 'loc-ny-01',
#     'type': 'headquarters',
#     'address': {'street': '500 Fifth Avenue',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'USA',
#      'postalCode': '10110'}},
#    {'locationId': 'loc-sf-02',
#     'type': 'branch',
#     'address': {'street': '200 Market Street',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'USA',
#      'postalCode': '94105'}}]},
#  'users': [{'userId': 'u-001',
#    'profile': {'firstName': 'Alice',
#     'lastName': 'Johnson',
#     'dob': '1990-04-12',
#     'gender': 'female'},
#    'credentials': {'username': 'alice.j',
# ...

# %%
content['organization']['locations'][0]['address']['country'] = 'India'

# %%
content
# Out:
# {'metadata': {'requestId': 'req-9f23ab12',
#   'generatedAt': '2025-12-16T08:45:00Z',
#   'source': 'sample-data-generator',
#   'version': '1.0.0'},
#  'organization': {'id': 'org-1001',
#   'name': 'Acme Corporation',
#   'industry': 'Technology',
#   'isActive': True,
#   'contact': {'email': 'contact@acme.com', 'phone': '+1-555-123-4567'},
#   'locations': [{'locationId': 'loc-ny-01',
#     'type': 'headquarters',
#     'address': {'street': '500 Fifth Avenue',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'India',
#      'postalCode': '10110'}},
#    {'locationId': 'loc-sf-02',
#     'type': 'branch',
#     'address': {'street': '200 Market Street',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'USA',
#      'postalCode': '94105'}}]},
#  'users': [{'userId': 'u-001',
#    'profile': {'firstName': 'Alice',
#     'lastName': 'Johnson',
#     'dob': '1990-04-12',
#     'gender': 'female'},
#    'credentials': {'username': 'alice.j',
# ...

# %%
with open("file_txt.json",mode = "w")as file:
    json.dump(content,file)
